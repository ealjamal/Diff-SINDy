# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import torch
import torch.nn as nn
from pyDOE import lhs

from architectures.FourierFeatures import FourierFeatures
from architectures.MLP import MLP
from architectures.MultiTaskMLP import MultiTaskMLP
from training.Trainer import Trainer
from inference.PDESR import PDESR

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)
# Out:
# Device: cuda

# %% [markdown]
# # Data Loading

# %%
# Load data

data = scipy.io.loadmat('./Data/burgers_shock_mu_01_pi.mat')
x = data['x'].flatten()
t = data['t'].flatten()
usol = data['usol']

X, T = np.meshgrid(x, t, indexing='ij')
lower_bound = np.array([X.min(), T.min()])
upper_bound = np.array([X.max(), T.max()])

# %%
# Initial conditions

xt_ic = np.hstack([X[:, 0][:, None], T[:, 0][:, None]])
u_ic = usol[:, 0][:, None]

xt_ic = torch.from_numpy(xt_ic).float().to(DEVICE)
u_ic = torch.from_numpy(u_ic).float().to(DEVICE)

# %%
# Boundary conditions

xt_bc_left = np.hstack([X[0, :][:, None], T[0, :][:, None]])    # x=x_min
u_bc_left = usol[0, :][:, None]

xt_bc_right = np.hstack([X[-1, :][:, None], T[-1, :][:, None]]) # x=x_max
u_bc_right = usol[-1, :][:, None]

xt_bc = np.vstack([xt_bc_left, xt_bc_right])
u_bc = np.vstack([u_bc_left, u_bc_right])

xt_bc = torch.from_numpy(xt_bc).float().to(DEVICE)
u_bc = torch.from_numpy(u_bc).float().to(DEVICE)

# %%
# Interior Points

mask_interior = (T != t.min()) & (X != x.min()) & (X != x.max())

X_flat = X[mask_interior][:, None]
T_flat = T[mask_interior][:, None]
U_flat = usol[mask_interior][:, None]

xt_data = torch.from_numpy(np.hstack([X_flat, T_flat])).float().to(DEVICE)
u_data = torch.from_numpy(U_flat).float().to(DEVICE)

# %%
# Collocation points

N_col = 10_000
xt_col = lhs(n=2, samples=N_col)
xt_col[:,0] = 2 * xt_col[:,0] - 1
xt_col = torch.from_numpy(xt_col).float().to(DEVICE)

# %%
xt_ic.shape, xt_bc.shape, xt_data.shape
# Out:
# (torch.Size([256, 2]), torch.Size([200, 2]), torch.Size([25146, 2]))

# %% [markdown]
# # Training

# %%
# Trainer settings
lhs_deriv = 'u_t'
deriv_library = ['u_x', 'u_xx']
add_const_coeff = False
input_names = ['x', 't']
coeffs_input_names = ['x', 'u']
n_epochs=1000
sol_warmup_n_epochs=200
sol_update_per_epoch=5
coeffs_update_per_epoch=5
lambda_pde_warmup_epochs=500
max_lambda_pde=1.0
sol_warmup_loss_weighting=False
fit_loss_weighting=True
lambda_ic=1.0
lambda_bc=1.0
lambda_data=1.0
lambda_pde=1.0
lambda_alpha=0.9
verbosity=10

# Solution model settings
num_frequencies = 20
scale = 1.
input_dim = 2
sol_hidden_dims = [512, 512, 512, 512]
sol_output_dim = 1
activation = nn.GELU()

# Coefficients model settings
shared_hidden_dims = [512, 512, 512, 512]
head_num_layers = 2
n_coeffs = len(deriv_library) + int(add_const_coeff)

# %%
sol_fourier_features = FourierFeatures(input_dim,
                                       num_frequencies=num_frequencies,
                                       scale=scale).to(dtype=torch.float32, device=DEVICE)
sol_model = MLP(input_dim=input_dim,
                hidden_dims=sol_hidden_dims,
                output_dim=sol_output_dim,
                activation=activation,
                fourier_features=sol_fourier_features).to(device=DEVICE)
sol_optimizer = torch.optim.Adam(sol_model.parameters(), lr=1e-4)
sol_lr_scheduler = None

# %%
coeffs_fourier_features = None
coeffs_model = MultiTaskMLP(input_dim=input_dim,
                            shared_hidden_dims=shared_hidden_dims,
                            head_num_layers=head_num_layers,
                            n_coeffs=n_coeffs,
                            activation=activation,
                            fourier_features=coeffs_fourier_features).to(device=DEVICE)
coeffs_optimizer = torch.optim.Adam(coeffs_model.parameters(), lr=1e-4)
fit_lr_scheduler = None

# %%
trainer = Trainer(lhs_deriv=lhs_deriv,
                  deriv_library=deriv_library,
                  add_const_coeff=add_const_coeff,
                  input_names=input_names,
                  coeffs_input_names=coeffs_input_names,
                  sol_optimizer=sol_optimizer,
                  coeffs_optimizer=coeffs_optimizer,
                  sol_lr_scheduler=sol_lr_scheduler,
                  fit_lr_scheduler=fit_lr_scheduler,
                  n_epochs=n_epochs,
                  sol_warmup_n_epochs=sol_warmup_n_epochs,
                  sol_update_per_epoch=sol_update_per_epoch,
                  coeffs_update_per_epoch=coeffs_update_per_epoch,
                  lambda_pde_warmup_epochs=lambda_pde_warmup_epochs,
                  max_lambda_pde=max_lambda_pde,
                  sol_warmup_loss_weighting=sol_warmup_loss_weighting,
                  fit_loss_weighting=fit_loss_weighting,
                  lambda_ic=lambda_ic,
                  lambda_bc=lambda_bc,
                  lambda_data=lambda_data,
                  lambda_pde=lambda_pde,
                  lambda_alpha=lambda_alpha,
                  verbosity=verbosity)

# %%
res = trainer.fit(sol_model=sol_model,
                  coeffs_model=coeffs_model,
                  X_ic=xt_ic, U_ic=u_ic, X_bc=xt_bc, U_bc=u_bc, X_data=xt_data, U_data=u_data, X_col=xt_col)
# Out:
# [SolWarmup] Ep 10/200 Total=6.924988e-01, IC=3.633154e-01, BC=1.070078e-03, Data=3.281133e-01, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 20/200 Total=3.907560e-01, IC=1.453459e-01, BC=8.196167e-03, Data=2.372140e-01, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 30/200 Total=1.584845e-01, IC=8.436498e-03, BC=2.721835e-02, Data=1.228297e-01, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 40/200 Total=9.606323e-02, IC=1.707338e-02, BC=1.109786e-02, Data=6.789199e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 50/200 Total=5.840504e-02, IC=5.986469e-03, BC=2.586452e-03, Data=4.983212e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 60/200 Total=4.406445e-02, IC=1.356764e-03, BC=1.848752e-03, Data=4.085894e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 70/200 Total=3.924567e-02, IC=1.683293e-03, BC=1.141225e-03, Data=3.642115e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 80/200 Total=3.532084e-02, IC=1.110709e-03, BC=7.710039e-04, Data=3.343913e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 90/200 Total=3.222645e-02, IC=5.931729e-04, BC=7.316891e-04, Data=3.090158e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 100/200 Total=2.976166e-02, IC=4.837359e-04, BC=5.115491e-04, Data=2.876638e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 110/200 Total=2.765192e-02, IC=3.160760e-04, BC=3.581468e-04, Data=2.697770e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 120/200 Total=2.588507e-02, IC=2.668595e-04, BC=2.786801e-04, Data=2.533953e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 130/200 Total=2.437497e-02, IC=2.162306e-04, BC=2.363067e-04, Data=2.392243e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 140/200 Total=2.307769e-02, IC=1.886442e-04, BC=1.982407e-04, Data=2.269080e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 150/200 Total=2.195585e-02, IC=1.679312e-04, BC=1.640584e-04, Data=2.162386e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 160/200 Total=2.098142e-02, IC=1.550688e-04, BC=1.366328e-04, Data=2.068972e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 170/200 Total=2.013034e-02, IC=1.453567e-04, BC=1.145276e-04, Data=1.987046e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 180/200 Total=1.938447e-02, IC=1.375111e-04, BC=9.523665e-05, Data=1.915172e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 190/200 Total=1.872935e-02, IC=1.277801e-04, BC=7.904010e-05, Data=1.852253e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [SolWarmup] Ep 200/200 Total=1.815311e-02, IC=1.180707e-04, BC=6.571462e-05, Data=1.796933e-02, L_IC=1.000000e+00, L_BC=1.000000e+00, L_data=1.000000e+00
# [Train] Ep 10/1000 Total=1.833299e+00, IC=9.363450e-05, BC=3.983915e-05, Data=1.207417e-02, PDE=4.677841e-01, L_IC=1.169625e+02, L_BC=1.350718e+02, L_data=1.497864e+02, L_pde=1.800000e-02
# [Train] Ep 20/1000 Total=1.296196e+00, IC=3.058758e-05, BC=8.135155e-06, Data=9.727681e-03, PDE=3.589197e-01, L_IC=2.221539e+02, L_BC=5.053308e+02, L_data=1.307249e+02, L_pde=3.800000e-02
# [Train] Ep 30/1000 Total=1.419572e+00, IC=8.134564e-05, BC=8.597741e-06, Data=7.925052e-03, PDE=3.558467e-01, L_IC=1.327498e+02, L_BC=3.285854e+02, L_data=1.748013e+02, L_pde=5.800000e-02
# [Train] Ep 40/1000 Total=1.118949e+00, IC=2.433980e-05, BC=8.752426e-06, Data=6.499275e-03, PDE=3.573728e-01, L_IC=4.927979e+02, L_BC=3.914578e+02, L_data=1.655036e+02, L_pde=7.800000e-02
# [Train] Ep 50/1000 Total=7.297344e-01, IC=4.085855e-05, BC=2.301943e-05, Data=5.353765e-03, PDE=3.451940e-01, L_IC=2.992952e+02, L_BC=3.118722e+02, L_data=1.263592e+02, L_pde=9.800000e-02
# [Train] Ep 60/1000 Total=1.639149e+00, IC=3.174510e-05, BC=3.352778e-05, Data=4.107548e-03, PDE=3.709260e-01, L_IC=5.982978e+02, L_BC=2.507079e+02, L_data=3.817316e+02, L_pde=1.180000e-01
# [Train] Ep 70/1000 Total=1.892771e+00, IC=1.507956e-04, BC=1.522385e-04, Data=3.488650e-03, PDE=4.701267e-01, L_IC=4.305048e+02, L_BC=3.909180e+02, L_data=4.882870e+02, L_pde=1.380000e-01
# [Train] Ep 80/1000 Total=1.580385e+00, IC=2.988463e-05, BC=1.898293e-05, Data=2.745230e-03, PDE=3.608199e-01, L_IC=4.523368e+02, L_BC=3.369007e+02, L_data=5.476635e+02, L_pde=1.580000e-01
# [Train] Ep 590/1000 Total=3.142671e-02, IC=3.543353e-06, BC=1.306643e-06, Data=8.143008e-05, PDE=1.330532e-02, L_IC=6.104865e+02, L_BC=1.372534e+03, L_data=1.739506e+02, L_pde=1.000000e+00
# [Train] Ep 600/1000 Total=1.801668e-02, IC=1.597260e-06, BC=4.575002e-07, Data=6.811642e-05, PDE=1.204045e-02, L_IC=3.615814e+02, L_BC=7.403340e+02, L_data=7.428435e+01, L_pde=1.000000e+00
# [Train] Ep 610/1000 Total=6.735571e-02, IC=9.792803e-06, BC=2.381549e-06, Data=9.592401e-05, PDE=2.864275e-02, L_IC=6.607952e+02, L_BC=1.787565e+03, L_data=2.917388e+02, L_pde=1.000000e+00
# [Train] Ep 620/1000 Total=1.274370e-01, IC=3.940794e-05, BC=4.090999e-06, Data=3.887366e-04, PDE=4.486221e-02, L_IC=9.430710e+02, L_BC=3.160197e+03, L_data=8.355761e+01, L_pde=1.000000e+00
# [Train] Ep 630/1000 Total=8.807306e-02, IC=1.758165e-05, BC=1.873808e-05, Data=9.457031e-05, PDE=3.342713e-02, L_IC=6.924603e+02, L_BC=7.854234e+02, L_data=2.934749e+02, L_pde=1.000000e+00
# [Train] Ep 640/1000 Total=4.163081e-02, IC=1.176448e-05, BC=9.247675e-06, Data=9.549995e-05, PDE=1.572810e-02, L_IC=3.708950e+02, L_BC=5.446562e+02, L_data=1.728013e+02, L_pde=1.000000e+00
# [Train] Ep 650/1000 Total=2.599739e-02, IC=1.116698e-06, BC=5.515358e-07, Data=5.642419e-05, PDE=1.133689e-02, L_IC=1.133796e+03, L_BC=1.270752e+03, L_data=2.249661e+02, L_pde=1.000000e+00
# [Train] Ep 660/1000 Total=2.165856e-02, IC=1.762993e-06, BC=2.052878e-06, Data=5.789292e-05, PDE=9.878063e-03, L_IC=4.867296e+02, L_BC=3.389020e+02, L_data=1.766481e+02, L_pde=1.000000e+00
# [Train] Ep 670/1000 Total=2.354881e-02, IC=1.317537e-05, BC=3.125848e-06, Data=8.551827e-05, PDE=1.173358e-02, L_IC=2.824336e+02, L_BC=5.619542e+02, L_data=7.410674e+01, L_pde=1.000000e+00
# [Train] Ep 680/1000 Total=2.142775e-02, IC=2.846667e-06, BC=1.255700e-06, Data=8.896543e-05, PDE=1.132338e-02, L_IC=7.668680e+02, L_BC=7.823527e+02, L_data=7.799602e+01, L_pde=1.000000e+00
# [Train] Ep 690/1000 Total=2.216522e-02, IC=8.284245e-07, BC=4.758269e-07, Data=6.657148e-05, PDE=1.190179e-02, L_IC=1.629391e+03, L_BC=1.426614e+03, L_data=1.236983e+02, L_pde=1.000000e+00
# [Train] Ep 700/1000 Total=3.681208e-02, IC=4.476262e-06, BC=1.028465e-05, Data=8.150386e-05, PDE=1.460522e-02, L_IC=7.505590e+02, L_BC=6.516075e+02, L_data=1.490188e+02, L_pde=1.000000e+00
# [Train] Ep 710/1000 Total=1.959506e-02, IC=3.645891e-06, BC=6.871095e-07, Data=5.394509e-05, PDE=9.997067e-03, L_IC=4.324351e+02, L_BC=1.562484e+03, L_data=1.287936e+02, L_pde=1.000000e+00
# [Train] Ep 720/1000 Total=2.681484e-02, IC=6.379954e-06, BC=3.532240e-06, Data=6.190150e-05, PDE=1.348155e-02, L_IC=4.239720e+02, L_BC=6.032610e+02, L_data=1.372748e+02, L_pde=1.000000e+00
# [Train] Ep 730/1000 Total=1.967018e-02, IC=3.293560e-06, BC=2.127690e-06, Data=5.107209e-05, PDE=8.562942e-03, L_IC=5.772162e+02, L_BC=7.248502e+02, L_data=1.500603e+02, L_pde=1.000000e+00
# [Train] Ep 740/1000 Total=1.328282e-02, IC=1.580731e-06, BC=9.114767e-07, Data=5.703138e-05, PDE=8.124132e-03, L_IC=3.653098e+02, L_BC=3.920789e+02, L_data=7.406213e+01, L_pde=1.000000e+00
# [Train] Ep 750/1000 Total=1.950946e-02, IC=1.646856e-06, BC=6.741961e-07, Data=3.897017e-05, PDE=7.537648e-03, L_IC=6.294103e+02, L_BC=7.449962e+02, L_data=2.677174e+02, L_pde=1.000000e+00
# [Train] Ep 760/1000 Total=1.942598e-02, IC=1.274504e-06, BC=3.545925e-07, Data=3.748249e-05, PDE=8.018857e-03, L_IC=1.013555e+03, L_BC=2.236376e+03, L_data=2.487119e+02, L_pde=1.000000e+00
# [Train] Ep 770/1000 Total=1.262134e-01, IC=2.215340e-05, BC=2.746030e-05, Data=7.032011e-05, PDE=5.126594e-02, L_IC=1.314152e+03, L_BC=9.506101e+02, L_data=2.805809e+02, L_pde=1.000000e+00
# [Train] Ep 780/1000 Total=7.294884e-02, IC=3.493272e-05, BC=1.891604e-05, Data=2.516635e-04, PDE=2.927920e-02, L_IC=3.699259e+02, L_BC=5.699365e+02, L_data=7.933678e+01, L_pde=1.000000e+00
# [Train] Ep 790/1000 Total=2.329857e-02, IC=7.518933e-06, BC=1.788760e-06, Data=4.740321e-05, PDE=1.068579e-02, L_IC=4.631172e+02, L_BC=7.010644e+02, L_data=1.661618e+02, L_pde=1.000000e+00
# [Train] Ep 800/1000 Total=1.469166e-02, IC=2.664499e-06, BC=1.106069e-06, Data=3.462377e-05, PDE=7.458539e-03, L_IC=5.378752e+02, L_BC=8.631528e+02, L_data=1.399400e+02, L_pde=1.000000e+00
# [Train] Ep 810/1000 Total=2.376911e-02, IC=2.953554e-06, BC=3.627537e-06, Data=4.145741e-05, PDE=1.210871e-02, L_IC=9.669302e+02, L_BC=4.749348e+02, L_data=1.708180e+02, L_pde=1.000000e+00
# [Train] Ep 820/1000 Total=1.619730e-02, IC=1.577786e-05, BC=1.915512e-06, Data=4.330898e-05, PDE=7.689201e-03, L_IC=1.890611e+02, L_BC=4.913267e+02, L_data=1.058436e+02, L_pde=1.000000e+00
# [Train] Ep 830/1000 Total=1.682283e-02, IC=1.891507e-06, BC=3.016128e-06, Data=2.921070e-05, PDE=6.971846e-03, L_IC=8.573187e+02, L_BC=8.238136e+02, L_data=1.966620e+02, L_pde=1.000000e+00
# [Train] Ep 840/1000 Total=1.896290e-02, IC=2.592292e-06, BC=1.072422e-06, Data=2.806886e-05, PDE=9.867463e-03, L_IC=8.050215e+02, L_BC=1.200147e+03, L_data=2.038388e+02, L_pde=1.000000e+00
# [Train] Ep 850/1000 Total=1.047068e-02, IC=1.602915e-06, BC=5.662387e-07, Data=3.947571e-05, PDE=6.728757e-03, L_IC=4.490328e+02, L_BC=9.248264e+02, L_data=6.329180e+01, L_pde=1.000000e+00
# [Train] Ep 860/1000 Total=1.079435e-02, IC=1.154549e-06, BC=1.172270e-06, Data=3.288154e-05, PDE=6.356022e-03, L_IC=8.177505e+02, L_BC=6.159316e+02, L_data=8.430746e+01, L_pde=1.000000e+00
# [Train] Ep 870/1000 Total=7.476349e-03, IC=6.929283e-07, BC=5.607694e-07, Data=2.741189e-05, PDE=5.146972e-03, L_IC=4.411493e+02, L_BC=5.027422e+02, L_data=6.354066e+01, L_pde=1.000000e+00
# [Train] Ep 880/1000 Total=1.257042e-02, IC=1.745540e-06, BC=1.212127e-06, Data=3.693417e-05, PDE=8.359367e-03, L_IC=6.334186e+02, L_BC=5.005328e+02, L_data=6.765250e+01, L_pde=1.000000e+00
# [Train] Ep 890/1000 Total=7.537202e-03, IC=1.453144e-06, BC=1.079081e-06, Data=2.557129e-05, PDE=4.590293e-03, L_IC=2.109199e+02, L_BC=2.614421e+02, L_data=9.222433e+01, L_pde=1.000000e+00
# [Train] Ep 900/1000 Total=8.810924e-03, IC=4.230210e-07, BC=3.625805e-07, Data=2.244318e-05, PDE=4.775501e-03, L_IC=7.845274e+02, L_BC=6.063864e+02, L_data=1.552226e+02, L_pde=1.000000e+00
# [Train] Ep 910/1000 Total=4.164394e-02, IC=1.680866e-05, BC=7.891150e-06, Data=1.193419e-04, PDE=1.774153e-02, L_IC=5.729355e+02, L_BC=5.925282e+02, L_data=8.041107e+01, L_pde=1.000000e+00
# [Train] Ep 920/1000 Total=2.346627e-02, IC=8.451275e-06, BC=4.816607e-06, Data=4.460809e-05, PDE=8.356936e-03, L_IC=3.202801e+02, L_BC=1.049839e+03, L_data=1.646764e+02, L_pde=1.000000e+00
# [Train] Ep 930/1000 Total=3.480103e-02, IC=1.026933e-05, BC=4.483158e-06, Data=3.225903e-05, PDE=7.458244e-03, L_IC=5.668842e+02, L_BC=8.427356e+02, L_data=5.500212e+02, L_pde=1.000000e+00
# [Train] Ep 940/1000 Total=1.984769e-02, IC=8.261149e-06, BC=1.207714e-06, Data=4.116666e-05, PDE=8.678033e-03, L_IC=3.535317e+02, L_BC=1.176725e+03, L_data=1.658607e+02, L_pde=1.000000e+00
# [Train] Ep 950/1000 Total=9.193312e-03, IC=1.364967e-06, BC=2.787760e-07, Data=2.478023e-05, PDE=4.313331e-03, L_IC=2.405884e+02, L_BC=5.485322e+02, L_data=1.775072e+02, L_pde=1.000000e+00
# [Train] Ep 960/1000 Total=8.397680e-03, IC=1.943792e-07, BC=1.296833e-07, Data=2.146570e-05, PDE=4.180183e-03, L_IC=1.705181e+03, L_BC=1.107266e+03, L_data=1.743457e+02, L_pde=1.000000e+00
# [Train] Ep 970/1000 Total=4.384928e-02, IC=3.048788e-05, BC=1.193767e-05, Data=1.294877e-04, PDE=1.366176e-02, L_IC=3.653378e+02, L_BC=6.477108e+02, L_data=8.739811e+01, L_pde=1.000000e+00
# [Train] Ep 980/1000 Total=5.465288e-02, IC=1.096105e-05, BC=6.470611e-06, Data=9.041879e-05, PDE=1.935318e-02, L_IC=9.169438e+02, L_BC=2.184543e+03, L_data=1.229137e+02, L_pde=1.000000e+00
# [Train] Ep 990/1000 Total=2.949370e-02, IC=2.138702e-05, BC=7.074555e-06, Data=2.555371e-04, PDE=1.572854e-02, L_IC=2.024821e+02, L_BC=3.711201e+02, L_data=2.664648e+01, L_pde=1.000000e+00
# [Train] Ep 1000/1000 Total=2.620253e-02, IC=1.725744e-05, BC=1.517251e-05, Data=1.218563e-04, PDE=1.105693e-02, L_IC=2.509404e+02, L_BC=2.264457e+02, L_data=6.055712e+01, L_pde=1.000000e+00

# %% [markdown]
# # Inference

# %%
pdesr = PDESR(trainer=trainer,
              niterations=100,
              early_stop_condition=(
                  "stop_if(loss, complexity) = loss < 1e-10 && complexity < 10"
                  ),
              timeout_in_seconds=5 * 60,
              maxsize=10,
              maxdepth=10,
              binary_operators=["*", "+", "-", "/"],
              unary_operators=["square", "cube", "exp", "cos", "sin"],
              constraints={
                  "/": (-1, 3),
                  "square": 3,
                  "cube": 3,
                  "exp": 3,
                  "sin": 3,
                  "cos": 3
                  },
              complexity_of_operators={"/": 2, "exp": 4, "cos": 2, "sin": 2},
              complexity_of_constants=1,
              model_selection='score',
              output_directory=None)

# %%
terms_res = pdesr.fit(xt_data)
# Out:
# Fitting SR on u_x coefficient...
# /usr/local/lib/python3.12/dist-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/pysr/sr.py:2265: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://ai.damtp.cam.ac.uk/pysr/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 1.840e+01
# Progress: 1 / 3100 total iterations (0.032%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.597e-01  0.000e+00  y = -0.0003464
# 6           3.166e-01  2.557e-02  y = sin(square(-0.44181)) + x
# 7           2.949e-01  7.087e-02  y = 1.8536 * ((x - u) - x)
# 9           2.213e-01  1.436e-01  y = (u - sin(0.87873 + 1.3709)) * -0.35372
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.830e+03
# Progress: 73 / 3100 total iterations (2.355%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u - 0.0026718) * -0.97289
# 7           3.390e-04  8.941e-08  y = ((u * -1.9729) + u) - -0.0026044
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.210e+03
# Progress: 114 / 3100 total iterations (3.677%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 7           3.390e-04  3.874e-07  y = u + ((u * -1.9729) - -0.0025998)
# 9           1.833e-04  3.074e-01  y = ((u * -1.9582) + u) - (x * -0.027202)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.500e+03
# Progress: 185 / 3100 total iterations (5.968%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 8           3.052e-04  4.021e-04  y = u * (-0.9979 - (square(u) * -0.038488))
# 9           1.770e-04  5.447e-01  y = ((x + 0.093024) * 0.02729) + (u * -0.95741)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.710e+03
# Progress: 250 / 3100 total iterations (8.065%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.835e-04  5.094e-01  y = (u * -0.95741) + (x * 0.02729)
# 9           1.770e-04  1.807e-02  y = ((x + 0.093024) * 0.02729) + (u * -0.95741)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.920e+03
# Progress: 305 / 3100 total iterations (9.839%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = (x * 0.0272) + (u * -0.95815)
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.270e+03
# Progress: 370 / 3100 total iterations (11.935%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = (x * 0.0272) + (u * -0.95815)
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.870e+03
# Progress: 447 / 3100 total iterations (14.419%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = (x * 0.0272) + (u * -0.95815)
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.010e+04
# Progress: 526 / 3100 total iterations (16.968%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = (x * 0.0272) + (u * -0.95815)
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.110e+04
# Progress: 606 / 3100 total iterations (19.548%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = (x * 0.0272) + (u * -0.95815)
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.090e+04
# Progress: 658 / 3100 total iterations (21.226%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = (x * 0.0272) + (u * -0.95815)
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.070e+04
# Progress: 736 / 3100 total iterations (23.742%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.702e-04  3.819e-02  y = (0.034189 * cube(x - -0.06772)) + (u * -0.96692)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.050e+04
# Progress: 796 / 3100 total iterations (25.677%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) - -0.0025987
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.702e-04  3.819e-02  y = (0.034189 * cube(x - -0.06772)) + (u * -0.96692)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.500e+03
# Progress: 857 / 3100 total iterations (27.645%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.626e-04  8.392e-02  y = ((cube(x - -0.15113) * -0.031914) + u) * -0.96635
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.960e+03
# Progress: 922 / 3100 total iterations (29.742%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.491e-02  y = (cube(x + 0.13379) * 0.03201) + (u * -0.96637)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.080e+03
# Progress: 967 / 3100 total iterations (31.194%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.504e-02  y = (u * -0.96633) + (cube(x + 0.13815) * 0.031821)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.410e+03
# Progress: 1028 / 3100 total iterations (33.161%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.504e-02  y = (u * -0.96633) + (cube(x + 0.13815) * 0.031821)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.470e+03
# Progress: 1103 / 3100 total iterations (35.581%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.504e-02  y = (u * -0.96633) + (cube(x + 0.13815) * 0.031821)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.270e+03
# Progress: 1143 / 3100 total iterations (36.871%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.504e-02  y = (u * -0.96633) + (cube(x + 0.13815) * 0.031821)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.630e+03
# Progress: 1230 / 3100 total iterations (39.677%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.030e+04
# Progress: 1303 / 3100 total iterations (42.032%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.090e+03
# Progress: 1352 / 3100 total iterations (43.613%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.970e+03
# Progress: 1417 / 3100 total iterations (45.710%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.900e+03
# Progress: 1473 / 3100 total iterations (47.516%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.410e+03
# Progress: 1537 / 3100 total iterations (49.581%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.250e+03
# Progress: 1603 / 3100 total iterations (51.710%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.390e+03
# Progress: 1640 / 3100 total iterations (52.903%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.290e+03
# Progress: 1697 / 3100 total iterations (54.742%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.650e+03
# Progress: 1759 / 3100 total iterations (56.742%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.460e+03
# Progress: 1827 / 3100 total iterations (58.935%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.150e+03
# Progress: 1888 / 3100 total iterations (60.903%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.990e+03
# Progress: 1938 / 3100 total iterations (62.516%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.210e+03
# Progress: 2010 / 3100 total iterations (64.839%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.090e+03
# Progress: 2069 / 3100 total iterations (66.742%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.520e+03
# Progress: 2114 / 3100 total iterations (68.194%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.490e+03
# Progress: 2191 / 3100 total iterations (70.677%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.920e+03
# Progress: 2245 / 3100 total iterations (72.419%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.840e+03
# Progress: 2308 / 3100 total iterations (74.452%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.640e+03
# Progress: 2381 / 3100 total iterations (76.806%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.770e+03
# Progress: 2423 / 3100 total iterations (78.161%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.550e+03
# Progress: 2479 / 3100 total iterations (79.968%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.120e+03
# Progress: 2539 / 3100 total iterations (81.903%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.310e+03
# Progress: 2598 / 3100 total iterations (83.806%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.790e+03
# Progress: 2656 / 3100 total iterations (85.677%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.190e+03
# Progress: 2697 / 3100 total iterations (87.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.410e+03
# Progress: 2771 / 3100 total iterations (89.387%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.788e-01  0.000e+00  y = x
# 3           3.458e-04  3.346e+00  y = u * -0.97287
# 5           3.390e-04  9.867e-03  y = (u * -0.97289) + 0.0025988
# 6           3.054e-04  1.044e-01  y = (cube(u) * 0.041253) - u
# 7           1.833e-04  5.104e-01  y = ((x * -0.028388) + u) * -0.95815
# 9           1.768e-04  1.813e-02  y = ((x * 0.027181) + (u * -0.95819)) + 0.0025547
# 10          1.624e-04  8.505e-02  y = (u * -0.96634) + (cube(x + 0.13815) * 0.031775)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ...
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.540e+03
# Progress: 2003 / 3100 total iterations (64.613%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.730e-08  3.156e-01  y = (cube(x - 0.6781) * 0.00049944) + 0.0034287
# 10          8.014e-08  9.697e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.740e+03
# Progress: 2068 / 3100 total iterations (66.710%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.730e-08  3.156e-01  y = (cube(x - 0.6781) * 0.00049944) + 0.0034287
# 10          8.014e-08  9.697e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.210e+03
# Progress: 2151 / 3100 total iterations (69.387%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.730e-08  3.156e-01  y = (cube(x - 0.6781) * 0.00049944) + 0.0034287
# 10          8.014e-08  9.697e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.860e+03
# Progress: 2226 / 3100 total iterations (71.806%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.730e-08  3.156e-01  y = (cube(x - 0.6781) * 0.00049944) + 0.0034287
# 10          8.014e-08  9.697e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.500e+03
# Progress: 2284 / 3100 total iterations (73.677%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.730e-08  3.156e-01  y = (cube(x - 0.6781) * 0.00049944) + 0.0034287
# 10          8.014e-08  9.697e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.020e+04
# Progress: 2373 / 3100 total iterations (76.548%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.730e-08  3.156e-01  y = (cube(x - 0.6781) * 0.00049944) + 0.0034287
# 10          8.014e-08  9.697e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.230e+03
# Progress: 2426 / 3100 total iterations (78.258%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.200e+03
# Progress: 2505 / 3100 total iterations (80.806%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.000e+04
# Progress: 2585 / 3100 total iterations (83.387%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.010e+03
# Progress: 2639 / 3100 total iterations (85.129%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.480e+03
# Progress: 2718 / 3100 total iterations (87.677%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.440e+03
# Progress: 2778 / 3100 total iterations (89.613%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.960e+03
# Progress: 2851 / 3100 total iterations (91.968%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.930e+03
# Progress: 2938 / 3100 total iterations (94.774%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.610e+03
# Progress: 2994 / 3100 total iterations (96.581%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# Expressions evaluated per second: 9.250e+03
# Progress: 3063 / 3100 total iterations (98.806%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.149e-07  0.000e+00  y = 0.0029369
# 5           1.956e-07  2.419e-01  y = (x * 0.00098252) + 0.0029369
# 7           1.334e-07  1.914e-01  y = cos(x - 0.30255) * 0.0036173
# 8           9.729e-08  3.157e-01  y = (cube(x - 0.66806) * 0.00050912) + 0.0034262
# 10          8.014e-08  9.692e-02  y = (cube(x) * ((u * 0.005896) + 0.0014735)) + 0.003328
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Finished SR on u_xx coefficient!
#   - outputs/20251130_212742_VkpvkM/hall_of_fame.csv

# %%
terms_res['u_x'] # 0, 1, 2, 4, 6
# Out:
# {'complexity': {0: 1, 1: 3, 2: 5, 3: 6, 4: 7, 5: 9, 6: 10},
#  'loss': {0: 0.27879986,
#   1: 0.000345774,
#   2: 0.0003390173,
#   3: 0.00030539653,
#   4: 0.0001833162,
#   5: 0.00017678915,
#   6: 0.00016237532},
#  'equation': {0: 'x',
#   1: 'u * -0.9728695',
#   2: '(u * -0.97289103) + 0.0025988456',
#   3: '(cube(u) * 0.0412528) - u',
#   4: '((x * -0.028387887) + u) * -0.95815486',
#   5: '((x * 0.027180633) + (u * -0.9581852)) + 0.002554741',
#   6: '(u * -0.9663392) + (cube(x + 0.13814926) * 0.03177467)'},
#  'score': {0: 0.0,
#   1: 3.3462320366318954,
#   2: 0.009867121962895771,
#   3: 0.10444010795473704,
#   4: 0.5103984999261755,
#   5: 0.018127375551841112,
#   6: 0.08504733380657209},
#  'sympy_format': {0: x,
#   1: u*(-0.9728695),
#   2: 0.0025988456 + u*(-0.97289103),
#   3: u**3*0.0412528 - u,
#   4: (u + x*(-0.028387887))*(-0.95815486),
#   5: u*(-0.9581852) + x*0.027180633 + 0.002554741,
#   6: u*(-0.9663392) + (x + 0.13814926)**3*0.03177467},
#  'lambda_format': {0: PySRFunction(X=>x),
#   1: PySRFunction(X=>u*(-0.9728695)),
#   2: PySRFunction(X=>0.0025988456 + u*(-0.97289103)),
#   3: PySRFunction(X=>u**3*0.0412528 - u),
#   4: PySRFunction(X=>(u + x*(-0.028387887))*(-0.95815486)),
#   5: PySRFunction(X=>u*(-0.9581852) + x*0.027180633 + 0.002554741),
#   6: PySRFunction(X=>u*(-0.9663392) + (x + 0.13814926)**3*0.03177467)}}

# %%
terms_res['u_xx']
# Out:
# {'complexity': {0: 1, 1: 5, 2: 7, 3: 8, 4: 10},
#  'loss': {0: 5.1487285e-07,
#   1: 1.9561713e-07,
#   2: 1.3339898e-07,
#   3: 9.7286986e-08,
#   4: 8.0144275e-08},
#  'equation': {0: '0.0029369364',
#   1: '(x * 0.0009825161) + 0.0029369434',
#   2: 'cos(x - 0.3025483) * 0.0036172771',
#   3: '(cube(x - 0.66806114) * 0.0005091175) + 0.0034261819',
#   4: '(cube(x) * ((u * 0.0058960365) + 0.0014734638)) + 0.003327989'},
#  'score': {0: 0.0,
#   1: 0.2419401616308722,
#   2: 0.19140742158891982,
#   3: 0.31567925831360744,
#   4: 0.09691839051439036},
#  'sympy_format': {0: 0.00293693640000000,
#   1: x*0.0009825161 + 0.0029369434,
#   2: cos(x - 1*0.3025483)*0.0036172771,
#   3: (x - 1*0.66806114)**3*0.0005091175 + 0.0034261819,
#   4: x**3*(u*0.0058960365 + 0.0014734638) + 0.003327989},
#  'lambda_format': {0: PySRFunction(X=>0.00293693640000000),
#   1: PySRFunction(X=>x*0.0009825161 + 0.0029369434),
#   2: PySRFunction(X=>cos(x - 1*0.3025483)*0.0036172771),
#   3: PySRFunction(X=>(x - 1*0.66806114)**3*0.0005091175 + 0.0034261819),
#   4: PySRFunction(X=>x**3*(u*0.0058960365 + 0.0014734638) + 0.003327989)}}
